# %%
Data Lake Formation + Glue
# AWS Glue - Use Case 2
from IPython.display import Image
Image(filename='glue2.png')

# %%
Building AWS Glue Job using PySpark
1: Pre-requisite
2: The Data 
3: Create IAM Role
4: Create S3 Bucket
5: Configure Data Lake
6: Configure and Run Crawler
7: Role Permission to the Catalog
8: Create Developer Endpoint
9: PySpark Coding in Notebook
10: Create Glue Job
11: Clean up

# %%
1: Pre-requisite - AWS Account, Pyspark transformation and actions

# %%
2: The Data 
    customers data set fields: {CUSTOMERID, CUSTOMERNAME, EMAIL, CITY, COUNTRY, TERRITORY, CONTACTFIRSTNAME, CONTACTLASTNAME}
    
    sales data set fields: {ORDERNUMBER, QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, DEALSIZE, CUSTOMERID}

# %%
from IPython.display import Image
Image(filename='glue3.PNG')

# %%
1.Check Schema of the Data
2. Query the Data from the Source
3. Update the Data
4. Aggregation Functions
5. Merge & Split Data Sets
6. Write / Load Data at the Destination

# %%
from IPython.display import Image
Image(filename='glue.PNG')

# %%
from IPython.display import Image
Image(filename='vpc.PNG')

# %%
1. Create Source S3 bucket put CSV file - csv- Name,AGe,Address, Birthday
2. Vpc endpoint for s3
3. setting up a vpc to connect to JDBC DataStores
